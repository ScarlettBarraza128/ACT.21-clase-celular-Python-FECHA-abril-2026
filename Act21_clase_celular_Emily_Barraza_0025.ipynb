# %% [markdown]
# <a href="https://colab.research.google.com/github/ScarlettBarraza128/ACT.21-clase-celular-Python-FECHA-abril-2026/blob/main/Act21_clase_celular_Emily_Barraza_0025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Emily Barraza NL = 7 Fecha 22/abril/2026
# ## Clase celular
#
# ![texto del vínculo](https://raw.githubusercontent.com/ScarlettBarraza128/ACT.21-clase-celular-Python-FECHA-abril-2026/refs/heads/main/INFOCLASE2.png)

# %%
class Celular:
    # 1. Metodo __init__ para inicializar atributos (constructor)
    def __init__(self, marca, modelo, precio):
        # Atributos encapsulados (datos únicos)
        self.marca = marca
        self.modelo = modelo
        self.precio = precio
        self.encendido = False

    # 2. Comportamientos (métodos)
    def encender(self):
        self.encendido = True
        print(f"El {self.modelo} de {self.marca} se ha encendido.")

    def mostrar_info(self):
        print(f"Celular: {self.marca} {self.modelo} - Precio: ${self.precio}")

# 3. Instanciar múltiples objetos con características únicas
celular1 = Celular("Apple", "iPhone 15", 999)
celular2 = Celular("Samsung", "Galaxy S24", 899)

# Llamadas a las funciones para cada objeto celular 1 y celular 2
print("Celular 1:")
celular1.mostrar_info()
celular1.encender()

print("\nCelular 2:")
celular2.encender()
celular2.mostrar_info()
print("Creador de sofware por Emily Barraza NL = 7")
print("programa terminado")
# Out:
# Celular 1:
# Celular: Apple iPhone 15 - Precio: $999
# El iPhone 15 de Apple se ha encendido.
#
# Celular 2:
# El Galaxy S24 de Samsung se ha encendido.
# Celular: Samsung Galaxy S24 - Precio: $899
# Creador de sofware por Emily Barraza NL = 7
# programa terminado

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/ScarlettBarraza128/ACT.21-clase-celular-Python-FECHA-abril-2026/refs/heads/main/logicafuncionamiento.png)
